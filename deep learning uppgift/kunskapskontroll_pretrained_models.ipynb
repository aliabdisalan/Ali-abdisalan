# %% [markdown]
# # Pretrained Models - Kunskapskontroll

# %% [markdown]
# **Obligatoriskt att fylla i uppgifterna nedan.**
#
# Namn: Ali abdisalan
#
# Vem du har presenterat för:
#
# Datum då du presenterade:
#
# **Kunskapskontrollen lämnas in på Omniway.**

# %% [markdown]
# **It is possible to load pretrained models which is a powerful concept.**

# %% [markdown]
# Model implementation:
# https://keras.io/api/applications/#usage-examples-for-image-classification-models
#
# Class list for ResNet50, for example tennis ball is 852:
# https://deeplearning.cms.waikato.ac.nz/user-guide/class-maps/IMAGENET/

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

# %%
model = ResNet50(weights='imagenet')

# %%
# img_path = 'zebra.jpg'
# img_path = 'linjal.jpg'
img_path = 'tennisboll.png'
img = image.load_img(img_path, target_size=(224, 224))
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=224x224>

# %%
x = image.img_to_array(img)
x.shape
# Out:
# (224, 224, 3)

# %%
x = np.expand_dims(x, axis=0)
x.shape
# Out:
# (1, 224, 224, 3)

# %%
# https://www.tensorflow.org/api_docs/python/tf/keras/applications/resnet50/preprocess_input
x = preprocess_input(x)

# %%
preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Predicted: [(u'n02504013', u'Indian_elephant', 0.82658225), (u'n01871265', u'tusker', 0.1122357), (u'n02504458', u'African_elephant', 0.061040461)]
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step
# Predicted: [('n04409515', 'tennis_ball', 0.9999969), ('n04039381', 'racket', 2.7892925e-06), ('n03942813', 'ping-pong_ball', 5.5036654e-08)]

# %% [markdown]
# # 1. Take some pictures yourself and predict their class.

# %%
#img = image.load_img('tomato.png', target_size=(224, 224))
img = image.load_img('bicycle.png', target_size=(224, 224))
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
preds = model.predict(x)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# Predicted: [('n03792782', 'mountain_bike', 0.6797117), ('n03208938', 'disk_brake', 0.1339056), ('n03887697', 'paper_towel', 0.036529317)]

# %% [markdown]
# # 2. Answer the question: Why is "Pretrained models" a very powerful concept?

# %%
#1.pretrained models come with already learned information, so you don't have to start from scratch. 
#this helps save time and effort when working on new tasks.

#2.pretrained models have learned a lot from big datasets, 
#so they're good at handling different tasks and can work well even with limited data.

#3.pretrained models make it easy for people without much experience to use powerful machine learning tools. 
#they are like ready-made tools that anyone can use without needing to be an expert.
